# %% [markdown]
# <a href="https://colab.research.google.com/github/Suhani-Singhal2131/Machine-Learning-/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#A series is a one dimensional labelled array capable of holding any data type .The axis labels are collectively called the index
# There are multiple ways to create a pandas series.
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
#Creating a Dataframe
data={
    'Name':['Jai','Princi','Gaurav','Anuj'],
    'Age':[27,24,22,32],
    'Address':['Delhi','Kanpur','Allahabad','Kannauj'],
    'Qualification':['Msc','MA','MCA','Phd']
}
df=pd.DataFrame(data)
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd

# %%
data_list=[['Jai',27],['Princi',24],['Gaurav',22],['Anuj',23]]
df2=pd.DataFrame(data_list)
columns=['Name','Age']
df2 = pd.DataFrame(data_list,columns=columns)
df2
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24
# 2  Gaurav   22
# 3    Anuj   23

# %%
#Selection and Indexing of Columns
df2[['Age','Name']]
# Out:
#    Age    Name
# 0   27     Jai
# 1   24  Princi
# 2   22  Gaurav
# 3   23    Anuj

# %%
#Creating a new Column
df2['Address']=['Delhi','Kanpur','Allahabad','Kannauj']
df2
# Out:
#      Name  Age    Address
# 0     Jai   27      Delhi
# 1  Princi   24     Kanpur
# 2  Gaurav   22  Allahabad
# 3    Anuj   23    Kannauj

# %%
#Removing Column
df2.drop('Address',axis=1,inplace=True)
df2
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24
# 2  Gaurav   22
# 3    Anuj   23

# %%
#Selecting Rows
df2.loc[0]
df2.iloc[2]
df2
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24
# 2  Gaurav   22
# 3    Anuj   23

# %%
#Selecting Subsets of Rows and Columns
df2.loc[[0,1]][["Name"]]
# Out:
#      Name
# 0     Jai
# 1  Princi

# %%
#Conditional Selection
#I want only those people whose age is above 25
df2[df2["Age"]>25]
# Out:
#   Name  Age
# 0  Jai   27

# %%
#I want people whose age is above 25 and their name is Suhani
df2[(df2["Age"]<25) & (df2["Name"] == 'Princi')]
# Out:
#      Name  Age
# 1  Princi   24

# %%
#Finding mIssing Data
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df = pd.DataFrame(data)
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
df.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %%
df.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.dropna(thresh=4)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
#Fill all missing values
df.fillna(0)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  0.0
# 2  0.0  3  3.0  0.0
# 3  4.0  4  0.0  0.0
# 4  5.0  5  0.0  5.0

# %%
values={'A':0,'B':100,'C':300,'D':400}
df.fillna(value=values)
# Out:
#      A  B      C      D
# 0  1.0  1    1.0    1.0
# 1  2.0  2    2.0  400.0
# 2  0.0  3    3.0  400.0
# 3  4.0  4  300.0  400.0
# 4  5.0  5  300.0    5.0

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.fillna(df.mean())
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  3.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       5 non-null      int64
#  2   C       3 non-null      float64
#  3   D       2 non-null      float64
# dtypes: float64(3), int64(1)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#               A         B    C         D
# count  4.000000  5.000000  3.0  2.000000
# mean   3.000000  3.000000  2.0  3.000000
# std    1.825742  1.581139  1.0  2.828427
# min    1.000000  1.000000  1.0  1.000000
# 25%    1.750000  2.000000  1.5  2.000000
# 50%    3.000000  3.000000  2.0  3.000000
# 75%    4.250000  4.000000  2.5  4.000000
# max    5.000000  5.000000  3.0  5.000000

# %%
df['A']+10
# Out:
# 0    11.0
# 1    12.0
# 2     NaN
# 3    14.0
# 4    15.0
# Name: A, dtype: float64

# %%
#DataFrames Applying Function
df.fillna(df.mean(),inplace=True)

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  3.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0

# %%
def square(x):
  return x**2

# %%
df['D']=df["B"].apply(square)

# %%
df
# Out:
#      A   B    C    D
# 0  1.0   1  1.0    1
# 1  2.0   4  2.0   16
# 2  3.0   9  3.0   81
# 3  4.0  16  2.0  256
# 4  5.0  25  2.0  625

# %%
#loading the dataset
df=pd.read_csv('/content/anime.csv')

# %%
df.head()
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
df.loc[2]['Title']
# Out:
# Rank                                                     3
# Title    Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...
# Score                                                 9.06
# Name: 2, dtype: object

# %%
#which anime has the highest score
#give me top 5 highest scoring anime
#which anime has the highest episode count
#animes with top 5 episode count
#which is the longest running anime

# %%
#make a new column for episode count
def extract_episodes(txt):
    check = False
    data = ""
    for i in txt:
        if i == ")":
            check = False
            return data
        if check == True:
            data = data + i
        if i == '(':
            check = True

df['Episodes']=df['Title'].apply(extract_episodes)
df['Episodes']= df['Episodes'].str.replace(" eps","")
df['Episodes'] = df['Episodes'].astype(int)
df
# Out:
#     Rank                                              Title  Score  Episodes
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04        51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04         1
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04       148
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04        13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03        13
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03         2
# ...

# %%
#make a new column for time stamp
def extraction_time(txt):
    check = False
    data = ""
    for i in range(len(txt)):
        if txt[i] == ')':
            for j in range(i+1,i+20):
                data += txt[j]

            return data
df['Total Time'] = df['Title'].apply(extraction_time)
df
# Out:
#     Rank                                              Title  Score  Episodes  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04        51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04         1
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04       148
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04        13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03        13
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03         2
# ...

# %%
#which anime has the highest score
df[df['Score'] == df['Score'].max()]['Title']
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# Name: Title, dtype: object

# %%
#give me top 5 highest scoring anime
df['Title'].head()
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# 1    Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...
# 2    Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...
# 3    Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...
# 4    Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...
# Name: Title, dtype: object
